# %% [markdown]
# ## Aggregate NDT Metrics for USA & Greece over last three months

# %%
import pandas
import MySQLdb
import pandas.io.sql as psql
import matplotlib
from datetime import datetime as dt
from bq2ipy import bigquery
import socket
import os

START_DATE="2012-07-01"
END_DATE="2012-09-30"

def get_short_host_and_ip_map(filename):
    f = open(filename, 'r')
    hmap = {}
    for line in f.readlines():
        (h,ip) = line.split()
        h = ".".join(h.split(".")[2:4])
        hmap[h] = ip
    return hmap

def get_bq_table_names_from_dates(start, end):
    months=[] # ['m_lab.2012_07', 'm_lab.2012_08', 'm_lab.2012_09', 'm_lab.2012_10' ]
    beginning = datetime.datetime.strptime(start, "%Y-%m-%d") 
    ending    = datetime.datetime.strptime(end, "%Y-%m-%d") 
    years = range(beginning.year, ending.year+1)
    month_curr = beginning.month
    for year_curr in years:
        from_date = datetime.datetime(year_curr, month_curr, 1)
        end_of_year = datetime.datetime(year_curr, 12, 31)
        if ending < end_of_year:
            to_date = ending
        else:
            to_date = end_of_year
        months += [ "m_lab.%s_%02d" % (year_curr, m) for m in range(from_date.month, to_date.month+1)]
    return months

# %% [markdown]
# ## Queries

# %%
def query_ndt_downloads(iplist, months):
    args = {}
    IPS=",".join(["'%s'" % ip for ip in iplist ]) # create a format like: 'ip1','ip2','ip3',...
    MONTHS=",".join(months)
    
    # direction = 1 is download.
    query="""
select  
    UTC_USEC_TO_DAY(web100_log_entry.log_time*1000000) as date,
    count(test_id) as test_count,
    web100_log_entry.connection_spec.local_ip as server_ip,
    count(distinct web100_log_entry.connection_spec.remote_ip) as unique_clients,
    SUM(web100_log_entry.snap.HCThruOctetsAcked) as total_bytes,
    SUM(web100_log_entry.snap.SndLimTimeRwin +
        web100_log_entry.snap.SndLimTimeCwnd +
        web100_log_entry.snap.SndLimTimeSnd) as total_time
from    
    %(months)s
where 
        IS_EXPLICITLY_DEFINED(project)
    AND project = 0
    AND IS_EXPLICITLY_DEFINED(connection_spec.data_direction)
    AND connection_spec.data_direction = 1
    AND IS_EXPLICITLY_DEFINED(web100_log_entry.is_last_entry)
    AND web100_log_entry.is_last_entry = True
    AND IS_EXPLICITLY_DEFINED(web100_log_entry.snap.HCThruOctetsAcked)
    AND web100_log_entry.snap.HCThruOctetsAcked >= 8192
    AND web100_log_entry.snap.HCThruOctetsAcked < 1000000000
    AND (web100_log_entry.snap.SndLimTimeRwin +
         web100_log_entry.snap.SndLimTimeCwnd +
         web100_log_entry.snap.SndLimTimeSnd) >= 9000000
    AND (web100_log_entry.snap.SndLimTimeRwin +
         web100_log_entry.snap.SndLimTimeCwnd +
         web100_log_entry.snap.SndLimTimeSnd) < 3600000000
    AND IS_EXPLICITLY_DEFINED(web100_log_entry.snap.CongSignals)
    AND web100_log_entry.snap.CongSignals > 0
    AND IS_EXPLICITLY_DEFINED(web100_log_entry.connection_spec.remote_ip)
    AND IS_EXPLICITLY_DEFINED(web100_log_entry.connection_spec.local_ip)
    AND web100_log_entry.connection_spec.local_ip IN(%(ip_list)s) 
group by
    date, server_ip
order by
    date; 
""" % { 'ip_list' : IPS, 'months' : MONTHS }

    print query
    ret = bigquery(query)
    return ret

# %%
host_map   = get_short_host_and_ip_map("server-ips-usa.txt")
month_list = get_bq_table_names_from_dates(START_DATE, END_DATE)

ret = query_ndt_downloads(host_map.values(), month_list)
print ret
# Out:
# select
#     UTC_USEC_TO_DAY(web100_log_entry.log_time*1000000) as date,
#     count(test_id) as test_count,
#     web100_log_entry.connection_spec.local_ip as server_ip,
#     count(distinct web100_log_entry.connection_spec.remote_ip) as unique_clients,
#     SUM(web100_log_entry.snap.HCThruOctetsAcked) as total_bytes,
#     SUM(web100_log_entry.snap.SndLimTimeRwin +
#         web100_log_entry.snap.SndLimTimeCwnd +
#         web100_log_entry.snap.SndLimTimeSnd) as total_time
# from
#     m_lab.2012_07,m_lab.2012_08,m_lab.2012_09
# where
#         IS_EXPLICITLY_DEFINED(project)
#     AND project = 0
#     AND IS_EXPLICITLY_DEFINED(connection_spec.data_direction)
#     AND connection_spec.data_direction = 1
#     AND IS_EXPLICITLY_DEFINED(web100_log_entry.is_last_entry)
#     AND web100_log_entry.is_last_entry = True
#     AND IS_EXPLICITLY_DEFINED(web100_log_entry.snap.HCThruOctetsAcked)
#     AND web100_log_entry.snap.HCThruOctetsAcked >= 8192
#     AND web100_log_entry.snap.HCThruOctetsAcked < 1000000000
#     AND (web100_log_entry.snap.SndLimTimeRwin +
#          web100_log_entry.snap.SndLimTimeCwnd +
#          web100_log_entry.snap.SndLimTimeSnd) >= 9000000
#     AND (web100_log_entry.snap.SndLimTimeRwin +
#          web100_log_entry.snap.SndLimTimeCwnd +
#          web100_log_entry.snap.SndLimTimeSnd) < 3600000000
#     AND IS_EXPLICITLY_DEFINED(web100_log_entry.snap.CongSignals)
#     AND web100_log_entry.snap.CongSignals > 0
#     AND IS_EXPLICITLY_DEFINED(web100_log_entry.connection_spec.remote_ip)
#     AND IS_EXPLICITLY_DEFINED(web100_log_entry.connection_spec.local_ip)
#     AND web100_log_entry.connection_spec.local_ip IN('38.106.70.147','74.63.50.19','4.71.251.173','74.63.50.47','38.106.70.173','38.98.51.20','38.102.0.83','38.102.0.109','4.71.210.211','38.102.0.97','74.63.50.32','38.106.70.160','38.107.216.45','38.107.216.17','38.98.51.45','216.156.197.139','64.9.225.167','149.20.5.101','4.71.251.160','38.98.51.33','216.156.197.152','4.71.210.224','4.71.251.147','149.20.5.75','64.9.225.141','4.71.210.237','4.71.254.173','38.107.216.32','4.71.254.147','216.156.197.165','64.9.225.154','4.71.254.160','149.20.5.88')
# group by
#     date, server_ip
# order by
#     date;
#
 7358959266.0, 9255481251.0, 994301908.0, 11008700269.0, 9172216367.0, 7439299999.0, 9868123329.0, 7424089214.0, 10183362090.0, 10741976891.0, 8503380489.0, 11341953918.0, 11945073140.0, 974478502.0, 9519435916.0, 8993895398.0, 11694768047.0, 887354559.0, 20172474.0, 24818533526.0, 12987308950.0, 23085797219.0, 8122739918.0, 8717026588.0, 8309237240.0, 10902926464.0, 1128754104.0, 11270211911.0, 8864249332.0, 10926793915.0, 9417414182.0, 12352900881.0, 10519193574.0, 1627231437.0, 1552760014.0, 11041262778.0, 9442858088.0, 9115849004.0, 7620644863.0, 6888628631.0, 25511903508.0, 11016849597.0, 9488669823.0, 10864876003.0, 9228655833.0, 9491527145.0, 10918902532.0, 21797075781.0, 9387016633.0, 9100956943.0, 10972182386.0, 10621020188.0, 8776149342.0, 8961126271.0, 10978734431.0, 6451074848.0, 7913794528.0, 10498438251.0, 10735112424.0, 10100610771.0, 11525882508.0, 9480636562.0, 19723836788.0, 8084629901.0, 1515074395.0, 10086990374.0, 10805794394.0, 26510069849.0, 9925748486.0, 4531448717.0, 11300846072.0, 8286677412.0, 1789435190.0, 1521454635.0, 24909906590.0, 9629366340.0, 20262952265.0, 7692750802.0, 8523228083.0, 11043158484.0, 1 ...

# %% [markdown]
# ## TOTAL DATA

# %%
f=figure(figsize=(12,6))           
grid()

ylim(ymin=0,ymax=25)
xmin = datetime.datetime.strptime(START_DATE, "%Y-%m-%d") 
xmax = datetime.datetime.strptime(END_DATE, "%Y-%m-%d") 
xlim(xmin=xmin,xmax=xmax)

title("NDT Data")
ylabel("Avg Transfer Rates (Mbit/sec)", fontsize="large")
NAME=host_map.keys()
IPS=host_map.values()
colors=('red', 'darkred', 'crimson', 'navy', 'blue', 'skyblue', 'lightgreen', 'seagreen', 'forestgreen')
for idx,ip in enumerate(IPS):
    index_list = [ i for i,sip in enumerate(ret['server_ip']) if ip == sip ]
    date_list  = [ ret['date'][i] for i in index_list ]
    total_list = [ 8*ret['total_bytes'][i]/ret['total_time'][i] for i in index_list ]

    plot_date(matplotlib.dates.epoch2num([ x/1e6 for x in date_list ]),
          [ x for x in total_list ],
          xdate=True, ydate=False, 
          color=colors[idx%len(colors)], mec=colors[idx%len(colors)],
          linestyle='-', linewidth=1,markevery=2,
          marker='^', figure=f, markersize=8, label=NAME[idx])

legend(ncol=5, loc=2)

# %% [markdown]
# ## TOTAL TESTS

# %%
#f=figure(figsize=(12,6))           
#grid()

#ylim(ymin=0,ymax=15000)
#xmin = datetime.datetime.strptime("2012-07-01", "%Y-%m-%d") 
#xmax = datetime.datetime.strptime("2012-10-30", "%Y-%m-%d") 
#xlim(xmin=xmin,xmax=xmax)

#title("%s) Package %s, %s samples from %s, %2.1f%% pass" % (i, 
#                                                        package_list[affected_host][package_id], 
#                                                        total_samples, affected_host, percent_pass))
#ylabel("y-label") # this depends on the data set
            
#                # Plot raw-good, pass-bad, fail-bad, and average-good
#title("Total NDT Tests per Day in Greece")
#ylabel("Test Count", fontsize="large")
#GR_IPS=['83.212.4.10','83.212.4.24','83.212.4.37','83.212.5.139','83.212.5.152','83.212.5.164']
#GR_NAME=['mlab1.ath01','mlab2.ath01','mlab3.ath01','mlab1.ath02',  'mlab2.ath02', 'mlab3.ath02']
#colors=('red', 'darkred', 'crimson', 'navy', 'blue', 'skyblue')
#for idx,ip in enumerate(GR_IPS):
#    index_list = [ i for i,sip in enumerate(ret['gr']['up']['server_ip']) if ip == sip ]
#    date_list  = [ ret['gr']['up']['date'][i] for i in index_list ]
#    total_list = [ ret['gr']['up']['test_count'][i] for i in index_list ]#

#    plot_date(matplotlib.dates.epoch2num([ x/1e6 for x in date_list ]),
#          total_list,
#          xdate=True, ydate=False, 
#          color=colors[idx], mec=colors[idx],
#          linestyle='-', linewidth=1,markevery=2,
#          marker='^', figure=f, markersize=8, label=GR_NAME[idx])

#legend(ncol=3, loc=2)

# %%
#f=figure(figsize=(12,6))           
#grid()

#ylim(ymin=0,ymax=300)
#xmin = datetime.datetime.strptime("2012-07-01", "%Y-%m-%d") 
#xmax = datetime.datetime.strptime("2012-10-01", "%Y-%m-%d") 
#xlim(xmin=xmin,xmax=xmax)

#title("%s) Package %s, %s samples from %s, %2.1f%% pass" % (i, 
#                                                        package_list[affected_host][package_id], 
#                                                        total_samples, affected_host, percent_pass))
#ylabel("y-label") # this depends on the data set
            
#                # Plot raw-good, pass-bad, fail-bad, and average-good
#title("NDT Tests per Day in USA and Greece")
#ylabel("Tests per Day (Thousands)", fontsize="large")
#plot_date(matplotlib.dates.epoch2num([ x/1e6 for x in ret['us']['up']['date'] ]),
#          [ x/1e3 for x in ret['us']['up']['test_count'] ],
#          xdate=True, ydate=False, 
#          color='red', mec='white', mew=1.5,
##          linestyle='-', linewidth=3,markevery=2,
#          marker='^', figure=f, markersize=10, label="USA upload")
#plot_date(matplotlib.dates.epoch2num([ x/1e6 for x in ret['us']['down']['date'] ]),
#          [ x/1e3 for x in ret['us']['down']['test_count'] ],
#          xdate=True, ydate=False, 
#          color='blue', mec='white', mew=1.5,
#          linestyle='-', linewidth=3,markevery=2,
#          marker='v', figure=f, markersize=10, label="USA download")

#plot_date(matplotlib.dates.epoch2num([ x/1e6 for x in ret['gr']['up']['date'] ]),
#          [ x/1e3 for x in ret['gr']['up']['test_count'] ],
#          xdate=True, ydate=False, 
#          color='navy', mec='navy',
#          linestyle='-', linewidth=1,markevery=2,
#          marker='^', figure=f, markersize=8, label="Greece upload")
#plot_date(matplotlib.dates.epoch2num([ x/1e6 for x in ret['gr']['down']['date'] ]),
#          [ x/1e3 for x in ret['gr']['down']['test_count'] ],
#          xdate=True, ydate=False, 
#          color='orange', mec='orange',
#          linestyle='-', linewidth=1, markevery=2,
#          marker='v', figure=f, markersize=8, label="Greece download")
#legend(ncol=4, loc=2)
